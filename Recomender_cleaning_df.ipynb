# %%
import pandas as pd

# %%
hits_old = pd.read_csv("./hits_old.csv")

# %%
songs_dataset = pd.read_csv("./songs_1000.csv")

# %%
hits_now = pd.read_csv("./hits.csv")

# %%
hits_now.head()
# Out:
#    Unnamed: 0                 song                        artist
# 0           0            Positions                 Ariana Grande
# 1           1    Forever After All                    Luke Combs
# 2           2                 Mood  24kGoldn Featuring iann dior
# 3           3  Laugh Now Cry Later      Drake Featuring Lil Durk
# 4           4      Blinding Lights                    The Weeknd

# %%
hits_old.loc[:,"Song 1990":"Song 2010"]
# Out:
#                Song 1990                    Song 1991  \
# 0                Hold On                      Bad Day
# 1   Nothing Compares 2 U                  Temperature
# 2                 Poison                  Promiscuous
# 3                  Vogue             You're Beautiful
# 4         Vision Of Love               Hips Don't Lie
# ..                   ...                          ...
# 95                  Song                 Stupid Girls
# 96                  Song                Feel Good Inc
# 97                  Song                   I'm Sprung
# 98                  Song          Do I Make You Proud
# 99                  Song  For You I Will (Confidence)
#
#                       Song 1992                    Song 1993  \
# 0                       Bad Day                      Bad Day
# 1                   Temperature                  Temperature
# 2                   Promiscuous                  Promiscuous
# 3              You're Beautiful             You're Beautiful
# ...

# %%
songs_70=[]

# %%
test.append(hits_old["Song 1970"])

# %%
songs_70=[]
for year in hits_old.loc[:,"Song 1970":"Song 1979"]:
    for song in range(len(hits_old[year])):
        songs_70.append(hits_old[year][song])
     
    
songs_80=[]
for year in hits_old.loc[:,"Song 1980":"Song 1989"]:
    for song in range(len(hits_old[year])):
        songs_80.append(hits_old[year][song])
        
        
songs_90=[]
for year in hits_old.loc[:,"Song 1990":"Song 1999"]:
    for song in range(len(hits_old[year])):
        songs_90.append(hits_old[year][song])

        
songs_00=[]
for year in hits_old.loc[:,"Song 2000":"Song 2009"]:
    for song in range(len(hits_old[year])):
        songs_00.append(hits_old[year][song])

        
songs_10=[]
for year in hits_old.loc[:,"Song 2010":"Song 2019"]:
    for song in range(len(hits_old[year])):
        songs_10.append(hits_old[year][song])

# %%
len(songs_00)
# Out:
# 1000

# %%
old_hits = pd.DataFrame({"'70s":songs_70,
                        "'80s":songs_80,
                        "'90s":songs_90,
                        "'00s":songs_00,
                        "'10s":songs_10})

# %%
old_hits.head()
# Out:
#                                 '70s                            '80s  \
# 0         Bridge Over Troubled Water                           Magic
# 1     (They Long To Be) Close To You                   Rock With You
# 2    American Woman/No Sugar Tonight     Do That To Me One More Time
# 3  Raindrops Keep Fallin' On My Head  Crazy Little Thing Called Love
# 4                                War                       Funkytown
#
#                    '90s              '00s              '10s
# 0               Hold On           Bad Day           TiK ToK
# 1  Nothing Compares 2 U       Temperature      Need You Now
# 2                Poison       Promiscuous  Hey, Soul Sister
# 3                 Vogue  You're Beautiful  California Gurls
# 4        Vision Of Love    Hips Don't Lie               OMG

# %%
old_hits.to_csv("./old_hits.csv")
